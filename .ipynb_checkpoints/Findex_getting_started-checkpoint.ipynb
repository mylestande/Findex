# %% [markdown]
# # Findex 2021
#
# Financial inclusion is a cornerstone of development, and since 2011, the Global Findex Database has been the definitive source of data on global access to financial services from payments to savings and borrowing. The 2021 edition, based on nationally representative surveys of about 128,000 adults in 123 economies during the COVID-19 pandemic, contains updated indicators on access to and use of formal and informal financial services and digital payments, and offers insights into the behaviours that enable financial resilience. The data also identify gaps in access to and usage of financial services by women and poor adults.
#
# We will use the country-level data from 2021 (it is up to 2021 actually, including the data from 2011, 2014, 2017, and 2021). The data and codebook are publicly accessible here and are also available on Learn: https://www.worldbank.org/en/publication/globalfindex/Data
#
# The data is given in an Excel file, the first sheet includes the country-level data and the second sheet is the codebook describing the variables.

# %%
#import required packages
import pandas as pd
import numpy as np

# %%
#read-in the data- Sheet one is the data and the other ones are codebook
data = pd.read_excel('DatabankWide.xlsx', sheet_name="Data")

# %%
#see the first 5 rows
data.head()
# Out:
#   Country name Country code  Year  Adult populaiton  \
# 0  Afghanistan          AFG  2011       15124473.00
# 1  Afghanistan          AFG  2014       17300802.00
# 2  Afghanistan          AFG  2017       19718214.00
# 3  Afghanistan          AFG  2021       22647496.00
# 4      Albania          ALB  2011        2258899.75
#
#                                           Region         Income group  \
# 0                                     South Asia           Low income
# 1                                     South Asia           Low income
# 2                                     South Asia           Low income
# 3                                     South Asia           Low income
# 4  Europe & Central Asia (excluding high income)  Upper middle income
#
#    Account (% age 15+)  Financial institution account (% age 15+)  \
# 0             0.090050                                   0.090050
# 1             0.099610                                   0.099610
# 2             0.148933                                   0.145471
# 3             0.096538                                   0.096538
# 4             0.282681                                   0.282681
#
#    First financial institution account ever was opened to receive a wage payment or money from the government (% age 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    First financial institution account ever was opened to receive a wage payment (% age 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Used a mobile phone or the internet to access an account, young (% ages 15-24)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                NaN
# 4                                                NaN
#
#    Used a mobile phone or the internet to access an account, older (% age 25+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                            0.01469
# 3                                                NaN
# 4                                                NaN
#
#    Used a mobile phone or the internet to access an account, primary education or less (% ages 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                           0.003958
# 3                                                NaN
# 4                                                NaN
#
#    Used a mobile phone or the internet to access an account, secondary education or more (% ages 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                            0.02265
# 3                                                NaN
# 4                                                NaN
#
#    Used a mobile phone or the internet to access an account, income, poorest 40% (% ages 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                           0.003607
# 3                                                NaN
# 4                                                NaN
#
#    Used a mobile phone or the internet to access an account, income, richest 60% (% ages 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                            0.01282
# 3                                                NaN
# 4                                                NaN
#
#    Used a mobile phone or the internet to access an account, rural (% age 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Used a mobile phone or the internet to access an account, urban (% age 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Used a mobile phone or the internet to access an account, out of labor force (% age 15+)  \
# 0                                                NaN
# 1                                                NaN
# 2                                           0.000548
# 3                                                NaN
# 4                                                NaN
#
#    Used a mobile phone or the internet to access an account, in labor force (% age 15+)
# 0                                                NaN
# 1                                                NaN
# 2                                           0.017173
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 1232 columns]

# %%
#some variables are categorical, make sure to change their type to category
data[['Country name', 'Country code', 'Year', 'Region', 'Income group']] = data[['Country name', 'Country code', 'Year', 'Region', 'Income group']].astype('category')

# %%
print(data.dtypes)
# Out:
# Country name                                                                                  category
# Country code                                                                                  category
# Year                                                                                          category
# Adult populaiton                                                                               float64
# Region                                                                                        category
#                                                                                                 ...
# Used a mobile phone or the internet to access an account, income, richest 60% (% ages 15+)     float64
# Used a mobile phone or the internet to access an account, rural (% age 15+)                    float64
# Used a mobile phone or the internet to access an account, urban (% age 15+)                    float64
# Used a mobile phone or the internet to access an account, out of labor force (% age 15+)       float64
# Used a mobile phone or the internet to access an account, in labor force (% age 15+)           float64
# Length: 1232, dtype: object

# %%
data[['Country name', 'Year', 'Region', 'Income group']].describe()
# Out:
#        Country name  Year       Region Income group
# count           658   658          595          584
# unique          184     5            7            4
# top     Afghanistan  2017  High income  High income
# freq              4   169          178          182

# %%
#check how many observations there are for each year- the 2022 sample is small and mostly NA, so it's better not to use it
data[['Year']].value_counts()
# Out:
# Year
# 2017    169
# 2011    166
# 2014    162
# 2021    145
# 2022     16
# dtype: int64

# %%
#make a summary table
mean_by_year_income = data.groupby(['Year', 'Income group'])['Account (% age 15+)'].mean().reset_index()
mean_by_year_income
# Out:
#     Year         Income group  Account (% age 15+)
# 0   2011          High income             0.845062
# 1   2011           Low income             0.111227
# 2   2011  Lower middle income             0.253779
# 3   2011  Upper middle income             0.412672
# 4   2014          High income             0.895042
# 5   2014           Low income             0.180538
# 6   2014  Lower middle income             0.358471
# 7   2014  Upper middle income             0.531408
# 8   2017          High income             0.916004
# 9   2017           Low income             0.300291
# 10  2017  Lower middle income             0.446135
# 11  2017  Upper middle income             0.591781
# 12  2021          High income             0.956635
# 13  2021           Low income             0.377268
# 14  2021  Lower middle income             0.524844
# 15  2021  Upper middle income             0.685461
# 16  2022          High income                  NaN
# 17  2022           Low income             0.257815
# 18  2022  Lower middle income             0.487565
# 19  2022  Upper middle income             0.477428

# %%
#we can make a subset of the data with all the variables including a specific word, for example: Mobile 
#and use this smaller dataset if it makes some analysis easier
mobile_columns = data.filter(like='mobile')
mobile_columns = mobile_columns.dropna(how="all")
mobile_columns
# Out:
#      Used a mobile phone or the internet to check account balance (% age 15+)  \
# 1                                                  NaN
# 2                                             0.029472
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.050863
# ..                                                 ...
# 652                                           0.102000
# 653                                           0.188178
# 655                                                NaN
# 656                                           0.247712
# 657                                           0.405395
#
#      Used a mobile phone or the internet to check account balance (% with a financial institution account, age 15+)  \
# 1                                                  NaN
# 2                                             0.202594
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.129364
# ..                                                 ...
# 652                                           0.308723
# 653                                           0.474031
# 655                                                NaN
# 656                                           0.368548
# 657                                           0.548028
#
#      Use a mobile phone or the internet to make payments, buy things, or to send or receive money using a financial institution account (% age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                           0.151876
# 655                                                NaN
# 656                                                NaN
# 657                                           0.385591
#
#      Use a mobile phone or the internet to make payments, buy things, or to send or receive money using a financial institution account (% with a financial institution account, age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                           0.382584
# 655                                                NaN
# 656                                                NaN
# 657                                           0.521255
#
#      Use a mobile money account two or more times a month (% age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                           0.217261
# 655                                                NaN
# 656                                                NaN
# 657                                           0.103356
#
#      Use a mobile money account two or more times a month (% with a mobile money account, age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                           0.654590
# 655                                                NaN
# 656                                                NaN
# 657                                           0.564218
#
#      Store money using a mobile money account (% age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                           0.177244
# 655                                                NaN
# 656                                                NaN
# 657                                           0.077505
#
#      Store money using a mobile money account (% with a mobile money account acount, age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                           0.534022
# 655                                                NaN
# 656                                                NaN
# 657                                           0.423099
#
#      Can use a mobile money account without help from anyone, including a mobile money agent (% age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                           0.230625
# 655                                                NaN
# 656                                                NaN
# 657                                           0.108171
#
#      Can use a mobile money account without help from anyone, including a mobile money agent (% with a mobile money account, age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                           0.694855
# 655                                                NaN
# 656                                                NaN
# 657                                           0.590508
#
#      ...  \
# 1    ...
# 2    ...
# 3    ...
# 5    ...
# 6    ...
# ..   ...
# 652  ...
# 653  ...
# 655  ...
# 656  ...
# 657  ...
#
#      Used a mobile phone or the internet to access an account, young (% ages 15-24)  \
# 1                                                  NaN
# 2                                             0.000000
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.077698
# ..                                                 ...
# 652                                           0.193978
# 653                                                NaN
# 655                                                NaN
# 656                                           0.228630
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, older (% age 25+)  \
# 1                                                  NaN
# 2                                             0.014690
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.031579
# ..                                                 ...
# 652                                           0.213676
# 653                                                NaN
# 655                                                NaN
# 656                                           0.252606
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, primary education or less (% ages 15+)  \
# 1                                                  NaN
# 2                                             0.003958
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.013652
# ..                                                 ...
# 652                                           0.138501
# 653                                                NaN
# 655                                                NaN
# 656                                           0.116583
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, secondary education or more (% ages 15+)  \
# 1                                                  NaN
# 2                                             0.022650
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.077903
# ..                                                 ...
# 652                                           0.307265
# 653                                                NaN
# 655                                                NaN
# 656                                           0.355014
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, income, poorest 40% (% ages 15+)  \
# 1                                                  NaN
# 2                                             0.003607
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.009006
# ..                                                 ...
# 652                                           0.146160
# 653                                                NaN
# 655                                                NaN
# 656                                           0.166880
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, income, richest 60% (% ages 15+)  \
# 1                                                  NaN
# 2                                             0.012820
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.064028
# ..                                                 ...
# 652                                           0.248010
# 653                                                NaN
# 655                                                NaN
# 656                                           0.302514
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, rural (% age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                                NaN
# 655                                                NaN
# 656                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, urban (% age 15+)  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 652                                                NaN
# 653                                                NaN
# 655                                                NaN
# 656                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, out of labor force (% age 15+)  \
# 1                                                  NaN
# 2                                             0.000548
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.028606
# ..                                                 ...
# 652                                           0.137716
# 653                                                NaN
# 655                                                NaN
# 656                                           0.144359
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, in labor force (% age 15+)
# 1                                                  NaN
# 2                                             0.017173
# 3                                                  NaN
# 5                                                  NaN
# 6                                             0.055465
# ..                                                 ...
# 652                                           0.234405
# 653                                                NaN
# 655                                                NaN
# 656                                           0.306314
# 657                                                NaN
#
# [490 rows x 153 columns]

# %%
#you can choose one year to focus on
data_2021 = data.loc[data['Year'] == 2021]
data_2021
# Out:
#                                           Country name Country code  Year  \
# 3                                          Afghanistan          AFG  2021
# 7                                              Albania          ALB  2021
# 11                                             Algeria          DZA  2021
# 17                                           Argentina          ARG  2021
# 21                                             Armenia          ARM  2021
# ..                                                 ...          ...   ...
# 642  Latin America & Caribbean (excluding high income)          LAC  2021
# 645  Middle East & North Africa (excluding high inc...          MNA  2021
# 649                                         South Asia          SAS  2021
# 653         Sub-Saharan Africa (excluding high income)          SSA  2021
# 657                                              World          WLD  2021
#
#      Adult populaiton                                             Region  \
# 3        2.264750e+07                                         South Asia
# 7        2.348634e+06      Europe & Central Asia (excluding high income)
# 11       3.035215e+07  Middle East & North Africa (excluding high inc...
# 17       3.428881e+07  Latin America & Caribbean (excluding high income)
# 21       2.345923e+06      Europe & Central Asia (excluding high income)
# ..                ...                                                ...
# 642      4.526771e+08  Latin America & Caribbean (excluding high income)
# 645      2.731634e+08  Middle East & North Africa (excluding high inc...
# 649      1.344725e+09                                         South Asia
# 653      6.587700e+08         Sub-Saharan Africa (excluding high income)
# 657      5.776585e+09                                                NaN
#
#             Income group  Account (% age 15+)  \
# 3             Low income             0.096538
# 7    Upper middle income             0.441742
# 11   Lower middle income             0.440970
# 17   Upper middle income             0.716271
# 21   Upper middle income             0.553477
# ..                   ...                  ...
# 642                  NaN             0.729474
# 645                  NaN             0.480926
# 649                  NaN             0.678895
# 653                  NaN             0.550697
# 657                  NaN             0.761956
#
#      Financial institution account (% age 15+)  \
# 3                                     0.096538
# 7                                     0.441742
# 11                                    0.440970
# 17                                    0.663254
# 21                                    0.522469
# ..                                         ...
# 642                                   0.710044
# 645                                   0.469150
# 649                                   0.658343
# 653                                   0.396974
# 657                                   0.739735
#
#      First financial institution account ever was opened to receive a wage payment or money from the government (% age 15+)  \
# 3                                                  NaN
# 7                                             0.282540
# 11                                            0.349182
# 17                                            0.358641
# 21                                            0.220799
# ..                                                 ...
# 642                                           0.389696
# 645                                           0.192473
# 649                                           0.434108
# 653                                           0.183956
# 657                                                NaN
#
#      First financial institution account ever was opened to receive a wage payment (% age 15+)  \
# 3                                                  NaN
# 7                                             0.254148
# 11                                            0.260234
# 17                                            0.331710
# 21                                            0.194768
# ..                                                 ...
# 642                                           0.364618
# 645                                           0.141693
# 649                                           0.306103
# 653                                           0.159863
# 657                                                NaN
#
#      ...  \
# 3    ...
# 7    ...
# 11   ...
# 17   ...
# 21   ...
# ..   ...
# 642  ...
# 645  ...
# 649  ...
# 653  ...
# 657  ...
#
#      Used a mobile phone or the internet to access an account, young (% ages 15-24)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, older (% age 25+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, primary education or less (% ages 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, secondary education or more (% ages 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, income, poorest 40% (% ages 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, income, richest 60% (% ages 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, rural (% age 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, urban (% age 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, out of labor force (% age 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, in labor force (% age 15+)
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
# [145 rows x 1232 columns]

# %% [markdown]
# __Note__:
#
# - You can change a variable to binary if desired to have two levels of 0/1 and use it as a response variable in a logistic regression or other classification methods.
# - You can also use external data at country level for specific years and combine it with the existing data (according to name of the country) to answer different questions. Examples of such data could be, GDP per capita, CO2 emission, happiness level, education accessibility for women, human development index (HDI), life expectancy, poverty rate, Gini coefficient, etc. Some sources to find such data are, UN: https://data.un.org/Default.aspx and Worldbank: https://data.worldbank.org/?_gl=1*1w8s4l1*_gcl_au*MTQ0MDQ4MzE0LjE3MjQ0MTc5MDk.

# %%
#change name of variables for easier calling, for example
data_2021 = data_2021.rename(columns = {'Financial institution account (% age 15+)' : 'FinanInst-acc',
                              'Used a mobile phone or the internet to access an account, older (% age 25+)' : 'Mob-Int-old'})
data_2021
# Out:
#                                           Country name Country code  Year  \
# 3                                          Afghanistan          AFG  2021
# 7                                              Albania          ALB  2021
# 11                                             Algeria          DZA  2021
# 17                                           Argentina          ARG  2021
# 21                                             Armenia          ARM  2021
# ..                                                 ...          ...   ...
# 642  Latin America & Caribbean (excluding high income)          LAC  2021
# 645  Middle East & North Africa (excluding high inc...          MNA  2021
# 649                                         South Asia          SAS  2021
# 653         Sub-Saharan Africa (excluding high income)          SSA  2021
# 657                                              World          WLD  2021
#
#      Adult populaiton                                             Region  \
# 3        2.264750e+07                                         South Asia
# 7        2.348634e+06      Europe & Central Asia (excluding high income)
# 11       3.035215e+07  Middle East & North Africa (excluding high inc...
# 17       3.428881e+07  Latin America & Caribbean (excluding high income)
# 21       2.345923e+06      Europe & Central Asia (excluding high income)
# ..                ...                                                ...
# 642      4.526771e+08  Latin America & Caribbean (excluding high income)
# 645      2.731634e+08  Middle East & North Africa (excluding high inc...
# 649      1.344725e+09                                         South Asia
# 653      6.587700e+08         Sub-Saharan Africa (excluding high income)
# 657      5.776585e+09                                                NaN
#
#             Income group  Account (% age 15+)  FinanInst-acc  \
# 3             Low income             0.096538       0.096538
# 7    Upper middle income             0.441742       0.441742
# 11   Lower middle income             0.440970       0.440970
# 17   Upper middle income             0.716271       0.663254
# 21   Upper middle income             0.553477       0.522469
# ..                   ...                  ...            ...
# 642                  NaN             0.729474       0.710044
# 645                  NaN             0.480926       0.469150
# 649                  NaN             0.678895       0.658343
# 653                  NaN             0.550697       0.396974
# 657                  NaN             0.761956       0.739735
#
#      First financial institution account ever was opened to receive a wage payment or money from the government (% age 15+)  \
# 3                                                  NaN
# 7                                             0.282540
# 11                                            0.349182
# 17                                            0.358641
# 21                                            0.220799
# ..                                                 ...
# 642                                           0.389696
# 645                                           0.192473
# 649                                           0.434108
# 653                                           0.183956
# 657                                                NaN
#
#      First financial institution account ever was opened to receive a wage payment (% age 15+)  \
# 3                                                  NaN
# 7                                             0.254148
# 11                                            0.260234
# 17                                            0.331710
# 21                                            0.194768
# ..                                                 ...
# 642                                           0.364618
# 645                                           0.141693
# 649                                           0.306103
# 653                                           0.159863
# 657                                                NaN
#
#      ...  \
# 3    ...
# 7    ...
# 11   ...
# 17   ...
# 21   ...
# ..   ...
# 642  ...
# 645  ...
# 649  ...
# 653  ...
# 657  ...
#
#      Used a mobile phone or the internet to access an account, young (% ages 15-24)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Mob-Int-old  \
# 3            NaN
# 7            NaN
# 11           NaN
# 17           NaN
# 21           NaN
# ..           ...
# 642          NaN
# 645          NaN
# 649          NaN
# 653          NaN
# 657          NaN
#
#      Used a mobile phone or the internet to access an account, primary education or less (% ages 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, secondary education or more (% ages 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, income, poorest 40% (% ages 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, income, richest 60% (% ages 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, rural (% age 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, urban (% age 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, out of labor force (% age 15+)  \
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
#      Used a mobile phone or the internet to access an account, in labor force (% age 15+)
# 3                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 17                                                 NaN
# 21                                                 NaN
# ..                                                 ...
# 642                                                NaN
# 645                                                NaN
# 649                                                NaN
# 653                                                NaN
# 657                                                NaN
#
# [145 rows x 1232 columns]
